# %%
import xml.etree.ElementTree as ET
from xml.etree.ElementTree import Element
import pandas as pd


def get_author_info_from_article_num(root: Element, article_num: int):

    article = root.findall(".//PubmedArticle")[article_num]

    authors = article.findall(".//AuthorList/Author")

    title = article.find(".//ArticleTitle").text if article.find(".//ArticleTitle").text is not None else ""
    pmid = article.find(".//PMID").text if article.find(".//PMID").text is not None else ""
    year = article.find(".//PubDate/Year").text if article.find(".//DateRevised/Year").text is not None else ""

    keyword_list = [keyword.text for keyword in article.findall(".//KeywordList/Keyword")]

    mesh_list = [mesh.text for mesh in article.findall(".//MeshHeading/DescriptorName[@UI]")]
    
    authors_info = []
    
    for author in authors:

        forename = author.find(".//ForeName").text if author.find(".//ForeName") is not None else ""
        lastname = author.find(".//LastName").text if author.find(".//LastName") is not None else ""
        initials = author.find(".//Initials").text if author.find(".//Initials") is not None else ""
        identity = author.find(".//AffiliationInfo/Identifier[@Source='GRID']").text if author.find(".//AffiliationInfo/Identifier[@Source='GRID']") is not None else ""

        affiliation_list = [aff.text for aff in author.findall(".//Affiliation")]

        author_info = {
            "forename": forename,
            "lastname": lastname,
            "initials": initials,
            "identity": identity,
            "affiliation": affiliation_list
        }
        authors_info.append(author_info)
    
    output = {
        "title": title,
        "pmid": pmid,
        "year": year,
        "keyword_list": keyword_list,
        "mesh_list": mesh_list,
        "authors_info": authors_info
    }
    
    return output


def get_all_data_for_each_article(root, article_cap):

    data = []

    for i in range(article_cap):

        data.append(get_author_info_from_article_num(root, i))

    return data


def flatten_article_data(article_data):

    flattened_data = []

    for article in article_data:
        for author in article['authors_info']:
            for affiliation in author['affiliation']:
                flattened_dict = {
                    "title": article['title'],
                    "pmid": article['pmid'],
                    "year": article['year'],
                    "keyword_list": article['keyword_list'],
                    "mesh_list": article['mesh_list'],
                    "forename": author['forename'],
                    "lastname": author['lastname'],
                    "initials": author['initials'],
                    "identity": author['identity'],
                    "affiliation": affiliation
                }
                flattened_data.append(flattened_dict)

    return flattened_data

tree = ET.parse("pubmed_result_sjogren.xml")

root = tree.getroot()

# data = get_all_data_for_each_article(root, len(root.findall(".//PubmedArticle")))

data = get_all_data_for_each_article(root, 5)

flattened_data = flatten_article_data(data)

print(flattened_data)

df = pd.DataFrame(flattened_data)

print(df)
# Out:
# [{'forename': 'Ourania D', 'lastname': 'Argyropoulou', 'initials': 'OD', 'identity': '', 'affiliation': 'Department of Pathophysiology, School of Medicine, National and Kapodistrian University of Athens, Athens, Greece.'}, {'forename': 'Daphne M', 'lastname': 'Peelen', 'initials': 'DM', 'identity': '', 'affiliation': 'Department of Rheumatology, Amsterdam Rheumatology & Immunology Center.'}, {'forename': 'Ben G J C', 'lastname': 'Zwezerijnen', 'initials': 'BGJC', 'identity': '', 'affiliation': 'Department of Radiology and Nuclear Medicine.'}, {'forename': 'Esther J', 'lastname': 'Nossent', 'initials': 'EJ', 'identity': '', 'affiliation': 'Department of Pulmonary Medicine and Amsterdam Cardiovascular Sciences, Amsterdam UMC, Vrije Universiteit, Amsterdam, The Netherlands.'}, {'forename': 'Lilian J', 'lastname': 'Meijboom', 'initials': 'LJ', 'identity': '', 'affiliation': 'Department of Radiology and Nuclear Medicine.'}, {'forename': 'Otto S', 'lastname': 'Hoekstra', 'initials': 'OS', 'identity': '', 'affiliation': 'Department of Radiology and Nuclear Medicine.'}, {'forename': 'Conny J', 'lastname': 'Van der Laken', 'initials': 'CJ', 'identity': '', 'affiliation': 'Department of Rheumatology, Amsterdam Rheumatology & Immunology Center.'}, {'forename': 'Alexandre E', 'lastname': 'Voskuyl', 'initials': 'AE', 'identity': '', 'affiliation': 'Department of Rheumatology, Amsterdam Rheumatology & Immunology Center.'}, {'forename': 'G', 'lastname': 'Serralta San Martín', 'initials': 'G', 'identity': '', 'affiliation': 'Servicio de Medicina Interna, Hospital Universitario Infanta Sofía, San Sebastián de los Reyes (Madrid), España. Electronic address: gonzaloserralta@mac.com.'}, {'forename': 'J', 'lastname': 'Canora Lebrato', 'initials': 'J', 'identity': '', 'affiliation': 'Servicio de Medicina Interna, Hospital Universitario de Fuenlabrada, Fuenlabrada (Madrid), España.'}, {'forename': 'Oddbjørn', 'lastname': 'Bjordal', 'initials': 'O', 'identity': '', 'affiliation': 'Department of Ophthalmology, Østfold Hospital, Grålum, Norway.'}, {'forename': 'Katrine Brække', 'lastname': 'Norheim', 'initials': 'KB', 'identity': '', 'affiliation': 'Clinical Immunology Unit, Department of Internal Medicine, Stavanger University Hospital, Stavanger, Norway.'}, {'forename': 'Eyvind', 'lastname': 'Rødahl', 'initials': 'E', 'identity': '', 'affiliation': 'Department of Ophthalmology, Haukeland University Hospital, Bergen, Norway; Department of Clinical Medicine, University of Bergen, Bergen, Norway.'}, {'forename': 'Roland', 'lastname': 'Jonsson', 'initials': 'R', 'identity': '', 'affiliation': 'Broegelmann Research Laboratory, Department of Clinical Science, University of Bergen, Bergen, Norway; Department of Rheumatology, Haukeland University Hospital, Bergen, Norway.'}, {'forename': 'Roald', 'lastname': 'Omdal', 'initials': 'R', 'identity': '', 'affiliation': 'Clinical Immunology Unit, Department of Internal Medicine, Stavanger University Hospital, Stavanger, Norway; Broegelmann Research Laboratory, Department of Clinical Science, University of Bergen, Bergen, Norway. Electronic address: roald.omdal@lyse.net.'}, {'forename': 'Yanping', 'lastname': 'Zeng', 'initials': 'Y', 'identity': '', 'affiliation': 'Department of Neurology, Renmin Hospital, Wuhan University, Wuhan, China.'}, {'forename': 'Yin', 'lastname': 'Liu', 'initials': 'Y', 'identity': '', 'affiliation': 'Department of Neurology, Renmin Hospital, Wuhan University, Wuhan, China.'}, {'forename': 'Yanchun', 'lastname': 'Xie', 'initials': 'Y', 'identity': '', 'affiliation': 'Department of Neurology, Renmin Hospital, Wuhan University, Wuhan, China.'}, {'forename': 'Jingjing', 'lastname': 'Liang', 'initials': 'J', 'identity': '', 'affiliation': 'Department of Neurology, Renmin Hospital, Wuhan University, Wuhan, China.'}, {'forename': 'Jiabing', 'lastname': 'Kuang', 'initials': 'J', 'identity': '', 'affiliation': 'Department of Orthopedic, Wuhan Fourth Hospital, Wuhan, China.'}, {'forename': 'Zuneng' ...
#           forename             lastname initials identity  \
# 0        Ourania D         Argyropoulou       OD
# 1         Daphne M               Peelen       DM
# 2        Ben G J C          Zwezerijnen     BGJC
# 3         Esther J              Nossent       EJ
# 4         Lilian J             Meijboom       LJ
# 5           Otto S             Hoekstra       OS
# 6          Conny J        Van der Laken       CJ
# 7      Alexandre E              Voskuyl       AE
# 8                G  Serralta San Martín        G
# 9                J       Canora Lebrato        J
# 10        Oddbjørn              Bjordal        O
# 11  Katrine Brække              Norheim       KB
# 12          Eyvind               Rødahl        E
# 13          Roland              Jonsson        R
# 14           Roald                Omdal        R
# 15         Yanping                 Zeng        Y
# 16             Yin                  Liu        Y
# 17         Yanchun                  Xie        Y
# 18        Jingjing                Liang        J
# 19         Jiabing                Kuang        J
# 20          Zuneng                   Lu        Z
# 21              Yu                 Zhou        Y
#
#                                           affiliation
# 0   Department of Pathophysiology, School of Medic...
# 1   Department of Rheumatology, Amsterdam Rheumato...
# 2       Department of Radiology and Nuclear Medicine.
# 3   Department of Pulmonary Medicine and Amsterdam...
# 4       Department of Radiology and Nuclear Medicine.
# 5       Department of Radiology and Nuclear Medicine.
# 6   Department of Rheumatology, Amsterdam Rheumato...
# 7   Department of Rheumatology, Amsterdam Rheumato...
# 8   Servicio de Medicina Interna, Hospital Univers...
# 9   Servicio de Medicina Interna, Hospital Univers...
# 10  Department of Ophthalmology, Østfold Hospital,...
# 11  Clinical Immunology Unit, Department of Intern...
# 12  Department of Ophthalmology, Haukeland Univers...
# 13  Broegelmann Research Laboratory, Department of...
# 14  Clinical Immunology Unit, Department of Intern...
# 15  Department of Neurology, Renmin Hospital, Wuha...
# 16  Department of Neurology, Renmin Hospital, Wuha...
# 17  Department of Neurology, Renmin Hospital, Wuha...
# 18  Department of Neurology, Renmin Hospital, Wuha...
# 19  Department of Orthopedic, Wuhan Fourth Hospita...
# 20  Department of Neurology, Renmin Hospital, Wuha...
# 21  Department of Neurology, Renmin Hospital, Wuha...
